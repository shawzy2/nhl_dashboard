# %% [markdown]
# # Mine Events API

# %%
import json
import requests
import pprint
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ### Sample Game
# May 7th 2022, NYR vs PIT, gameId=2021030143
#
# ##### Retrieve gameId

# %%
teamId = 3
date = '2022-05-07'

r = requests.get(url=f'https://statsapi.web.nhl.com/api/v1/schedule?teamId={teamId}&date={date}')
d = r.json()
gameId = d['dates'][0]['games'][0]['gamePk']
gameId
# Out:
# 2021030143

# %% [markdown]
# ### Retrive Game Events
#
# * Collect Shots, blocked shots, missed shots, and goals
# * blocked shots will have no goalie
# * missed shots will have a no goalie and no blocker

# %%
# pull data from api
r = requests.get(url=f'https://statsapi.web.nhl.com/api/v1/game/{gameId}/feed/live')
d = r.json()
awayTeamId = d['gameData']['teams']['away']['id']
homeTeamId = d['gameData']['teams']['home']['id']
shots = [event for event in d['liveData']['plays']['allPlays'] \
         if event['result']['event'] in set(['Shot', 'Blocked Shot', 'Missed Shot', 'Goal']) ]

# get sets of fwd/def/goalies that appear in this game
forwards = set()
defensemen = set()
goalies = set()
for key, val in d['gameData']['players'].items():   
    if val['primaryPosition']['type'] == 'Forward':
        forwards.add(val['id'])
    elif val['primaryPosition']['type'] == 'Defenseman':
        defensemen.add(val['id'])
    elif val['primaryPosition']['type'] == 'Goalie':
        goalies.add(val['id'])

# %%
d['gameData']['teams']['away']['id']
# Out:
# 3

# %%
gameInfo = {
    'gameId': d['gamePk'],
    'dateTime': d['gameData']['datetime']['dateTime'],
    'awayTeamId': d['gameData']['teams']['away']['id'],
    'homeTeamId': d['gameData']['teams']['home']['id']
}

roster = [{
    'playerId': player['id'],
    'firstName': player['firstName'],
    'lastName': player['lastName'],
    'primaryNumber': player['primaryNumber'],
    'birthCity': player['birthCity'],
    'birthCountry': player['birthCountry'],
    'nationality': player['nationality'],
    'height': player['height'],
    'weight': player['weight'],
    'shootsCatches': player['shootsCatches'],
    'teamId': player['currentTeam']['id'],
    'position': player['primaryPosition']['abbreviation'],
} for pid, player in d['gameData']['players'].items()]

# %%
teams = [{
    'teamId': team['id'],
    'name': team['name'],
    'locationName': team['locationName'],
    'teamName': team['teamName'],
    'abbreviation': team['abbreviation'],
    'division': team['division']['nameShort'],
    'conference': team['conference']['name'],
    'firstYearOfPlay': team['firstYearOfPlay'],
    'venue': team['venue']['name'],
    'timezone': team['venue']['timeZone']['tz']
} for homeaway, team in d['gameData']['teams'].items()]

# %%
# for homeaway, team in d['gameData']['teams'].items():
#     pprint.pprint(team)
teams
# Out:
# [{'teamId': 3,
#   'name': 'New York Rangers',
#   'locationName': 'New York',
#   'teamName': 'Rangers',
#   'abbreviation': 'NYR',
#   'division': 'Metro',
#   'conference': 'Eastern',
#   'firstYearOfPlay': '1926',
#   'venue': 'Madison Square Garden',
#   'timezone': 'EDT'},
#  {'teamId': 5,
#   'name': 'Pittsburgh Penguins',
#   'locationName': 'Pittsburgh',
#   'teamName': 'Penguins',
#   'abbreviation': 'PIT',
#   'division': 'Metro',
#   'conference': 'Eastern',
#   'firstYearOfPlay': '1967',
#   'venue': 'PPG Paints Arena',
#   'timezone': 'EDT'}]

# %%
def calc_gametime_second(period, time):
    time_in_seconds = int(time[:2]) * 60 + int(time[3:])
    return (period - 1) * 1200 + time_in_seconds

# %%
# extract shots
shot_data = []
for shot in shots:
    shooter = 0
    goalie = 0
    blocker = 0
    for player in shot['players']:
        if player['playerType'] == 'Shooter' or player['playerType'] == 'Scorer':
            shooter = player['player']['id']
        if player['playerType'] == 'Goalie':
            goalie = player['player']['id']
        if player['playerType'] == 'Blocker':
            blocker = player['player']['id']    
            
    # normalized shot locations
    x = shot['coordinates']['x']
    y = shot['coordinates']['y']
    if shot['about']['period'] % 2: # e.g., 2nd period, 1st ot period, 3rd ot period
        x = -1*x
        y = -1*y
        
    
    shot_data.append({
        'shooterId': shooter,
        'goalieId': goalie,
        'blockerId': blocker,
        'teamId': shot['team']['id'],
        'x': x,
        'y': y,
        'time': calc_gametime_second(shot['about']['period'], shot['about']['periodTime']),
        'type': shot['result']['eventTypeId']
    })

# %%
# read as dataframe
df_shots = pd.DataFrame(shot_data)
df_shots.head()
# Out:
#    shooterId  goalieId  blockerId  teamId     x     y  time         type
# 0    8475810   8478048          0       5 -52.0  21.0    27         SHOT
# 1    8476458   8475839          0       3  79.0  15.0    79         SHOT
# 2    8481554   8475839          0       3  74.0  30.0    85         SHOT
# 3    8482109         0          0       3  83.0  -7.0    87  MISSED_SHOT
# 4    8476934   8478048          0       5 -89.0   8.0   117         GOAL

# %%
# generate sample plots to ensure shot location transformations are correct
df_tmp = df_shots[df_shots['time'] < 1200] # 1st period
# df_tmp = df_shots[(df_shots['time'] > 1200) & (df_shots['time'] < 2400)] # 2nd period
# df_tmp = df_shots[(df_shots['time'] > 2400) & (df_shots['time'] < 3600)] # 2nd period

df_tmp['color'] = np.where(df_tmp['teamId']==3, 'blue', 'black')


df_tmp.plot.scatter(x='x', y='y',c='color')
# Out:
# /var/folders/ll/7dqm5ml15lb384fy0jvks7fr0000gn/T/ipykernel_53441/646940964.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp['color'] = np.where(df_tmp['teamId']==3, 'blue', 'black')
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ### Retrieve Time on Ice data
#
# Start by retrieving data from api

# %%
def calc_gametime_second(period, time):
    time_in_seconds = int(time[:2]) * 60 + int(time[3:])
    return (period - 1) * 1200 + time_in_seconds

def extract_json_shifts(d):
    return [{
        'gameId': shift['gameId'],
        'teamId': shift['teamId'],
        'playerId': shift['playerId'],
        'start': calc_gametime_second(shift['period'], shift['startTime']),
        'end': calc_gametime_second(shift['period'], shift['endTime'])
    } for shift in d['data']]

# %%
all_shifts = []
try:
    # get data for this game_id
    r = requests.get(url=f'https://api.nhle.com/stats/rest/en/shiftcharts?cayenneExp=gameId={gameId}')
    d = r.json()

    # extract shift data
    all_shifts.extend(extract_json_shifts(d))

except:
    print('could not fetch gameId: ' + gameId)

# %%
# convert to df
df_shifts = pd.DataFrame(all_shifts)

# some shifts are recorded with identical start/end times, omit these rows
df_shifts = df_shifts[df_shifts['start'] != df_shifts['end']]

# sort df
df_shifts = df_shifts.sort_values(['gameId', 'teamId', 'start', 'end', 'playerId'])
df_shifts.head(10)
# Out:
#          gameId  teamId  playerId  start   end
# 319  2021030143       3   8476885      0    34
# 726  2021030143       3   8480817      0    35
# 265  2021030143       3   8476459      0    41
# 568  2021030143       3   8478366      0    42
# 151  2021030143       3   8475184      0    43
# 556  2021030143       3   8478048      0  1200
# 675  2021030143       3   8479323     34    71
# 126  2021030143       3   8474027     35    70
# 635  2021030143       3   8478550     41    80
# 244  2021030143       3   8476458     42    80

# %%
# convert back to dict so we can identify line combinations
shifts = df_shifts.to_dict(orient='records')
shifts[0]
# Out:
# {'gameId': 2021030143, 'teamId': 3, 'playerId': 8476885, 'start': 0, 'end': 34}

# %% [markdown]
# ##### Then group players by line

# %%
def line_list_to_shift(line_list, start, end):
    # need this for when dataset changes from teamId_1 to teamId_2
    # ...corrects end time of final shift 'first' team's shift data
    if end <= start:
        end = line_list[0]['end']
    return {
        'playerIds': [player['playerId'] for player in line_list],
        'start': start,
        'end': end,
        'numPlayers': len(line_list),
        'teamId': line_list[0]['teamId']
    }

def next_shift_end(line_list):
    return min([player['end'] for player in line_list])

# %%
# get starting lines
start_time = shifts[0]['start']
line_list = []
line_shifts = []
i = 0

while i < len(shifts)-1: #and shifts[i]['teamId'] == 6:
    # add players starting shift
    while start_time == shifts[i]['start']:
        line_list.append(shifts[i])
        i += 1
        if i == len(shifts):
            i -= 1 # at the end of shifts data for this game
            break
    
    # figure out the time when the next player is getting on/off the ice
    next_player_off = next_shift_end(line_list)
    next_player_on = shifts[i]['start']
    end_time = min([next_player_off, next_player_on])

    # new player getting on, save this line combination
    line_shifts.append(line_list_to_shift(line_list, start_time, end_time))

    # cut list to only contain players that remain on the ice after end_time
    line_list = [player for player in line_list if player['end'] > end_time]
    
    # if reached end of shifts for this game for this team, clear line_list
    if next_player_on == 0:
        line_list = []

    # update start_time with time that new player(s) are getting on the ice
    start_time = end_time

# %%
pd.DataFrame(line_shifts)
# Out:
#                                              playerIds  start   end  \
# 0    [8476885, 8480817, 8476459, 8478366, 8475184, ...      0    34
# 1    [8480817, 8476459, 8478366, 8475184, 8478048, ...     34    35
# 2    [8476459, 8478366, 8475184, 8478048, 8479323, ...     35    41
# 3    [8478366, 8475184, 8478048, 8479323, 8474027, ...     41    42
# 4    [8475184, 8478048, 8479323, 8474027, 8478550, ...     42    43
# ..                                                 ...    ...   ...
# 474  [8475839, 8471724, 8476875, 8470604, 8476934, ...   3496  3529
# 475  [8475839, 8471724, 8470604, 8476934, 8471675, ...   3529  3533
# 476  [8475839, 8475722, 8470619, 8476927, 8477244, ...   3533  3567
# 477  [8475839, 8470619, 8476927, 8477244, 8478017, ...   3567  3568
# 478  [8475839, 8477244, 8478017, 8478046, 8477953, ...   3568  3600
#
#      numPlayers  teamId
# 0             6       3
# 1             6       3
# 2             6       3
# 3             6       3
# 4             6       3
# ..          ...     ...
# 474           6       5
# 475           6       5
# 476           6       5
# 477           6       5
# 478           6       5
#
# [479 rows x 5 columns]

# %% [markdown]
# ##### Next compute the num players on the ice for each team
#
# This will help with calculating scenarios in SQL queries (e.g., 5on5 or 5on4)

# %%
away_shifts = [s for s in line_shifts if s['teamId']==awayTeamId]
away_shifts_frames = []
for s in away_shifts:
    for i in range(s['start'], s['end']):
        away_shifts_frames.append({
            'awayPlayerIds': s['playerIds'],
            'time': i
        })
        
home_shifts = [s for s in line_shifts if s['teamId']==homeTeamId]
home_shifts_frames = []
for s in home_shifts:
    for i in range(s['start'], s['end']):
        home_shifts_frames.append({
            'homePlayerIds': s['playerIds'],
            'time': i
        })

# %%
df = pd.DataFrame(away_shifts_frames).merge(pd.DataFrame(home_shifts_frames), on='time')
df = df[['time', 'awayPlayerIds', 'homePlayerIds']]
df['awayNumPlayers'] = df['awayPlayerIds'].str.len()
df['homeNumPlayers'] = df['homePlayerIds'].str.len()
df
# Out:
#       time                                      awayPlayerIds  \
# 0        0  [8476885, 8480817, 8476459, 8478366, 8475184, ...
# 1        1  [8476885, 8480817, 8476459, 8478366, 8475184, ...
# 2        2  [8476885, 8480817, 8476459, 8478366, 8475184, ...
# 3        3  [8476885, 8480817, 8476459, 8478366, 8475184, ...
# 4        4  [8476885, 8480817, 8476459, 8478366, 8475184, ...
# ...    ...                                                ...
# 3595  3595  [8475747, 8478211, 8478366, 8479291, 8480382, ...
# 3596  3596  [8475747, 8478211, 8478366, 8479291, 8480382, ...
# 3597  3597  [8475747, 8478211, 8478366, 8479291, 8480382, ...
# 3598  3598  [8475747, 8478211, 8478366, 8479291, 8480382, ...
# 3599  3599  [8475747, 8478211, 8478366, 8479291, 8480382, ...
#
#                                           homePlayerIds  awayNumPlayers  \
# 0     [8477404, 8471675, 8475810, 8476875, 8471724, ...               6
# 1     [8477404, 8471675, 8475810, 8476875, 8471724, ...               6
# 2     [8477404, 8471675, 8475810, 8476875, 8471724, ...               6
# 3     [8477404, 8471675, 8475810, 8476875, 8471724, ...               6
# 4     [8477404, 8471675, 8475810, 8476875, 8471724, ...               6
# ...                                                 ...             ...
# 3595  [8475839, 8477244, 8478017, 8478046, 8477953, ...               6
# 3596  [8475839, 8477244, 8478017, 8478046, 8477953, ...               6
# 3597  [8475839, 8477244, 8478017, 8478046, 8477953, ...               6
# 3598  [8475839, 8477244, 8478017, 8478046, 8477953, ...               6
# 3599  [8475839, 8477244, 8478017, 8478046, 8477953, ...               6
#
#       homeNumPlayers
# 0                  6
# 1                  6
# 2                  6
# 3                  6
# 4                  6
# ...              ...
# 3595               6
# 3596               6
# 3597               6
# 3598               6
# 3599               6
#
# [3600 rows x 5 columns]

# %% [markdown]
# ##### Separate playerIds by position
# make columns for fwd/def/goalie and serialize data (i.e., [8476885, 8480817, 8476459] -> '8476885_8480817_8476459')

# %%
df['awayPlayerIds'][0]
# Out:
# [8476885, 8480817, 8476459, 8478366, 8475184, 8478048]

# %%
timeframes = df.to_dict(orient='records')

# %%
def serialize_ids(playerIds):
    return '_'.join(str(i) for i in sorted(playerIds))

# %%
serialized_shifts = []
for t in timeframes:
    serialized_shifts.append({
        'gameId': gameId,
        'time': t['time'],
        'awayNumPlayers': t['awayNumPlayers'],
        'awayFwdIds': serialize_ids([playerId for playerId in t['awayPlayerIds'] if playerId in forwards]),
        'awayDefIds': serialize_ids([playerId for playerId in t['awayPlayerIds'] if playerId in defensemen]),
        'awayGoalieIds': serialize_ids([playerId for playerId in t['awayPlayerIds'] if playerId in goalies]),
        'homeFwdIds': serialize_ids([playerId for playerId in t['homePlayerIds'] if playerId in forwards]),
        'homeDefIds': serialize_ids([playerId for playerId in t['homePlayerIds'] if playerId in defensemen]),
        'homeGoalieIds': serialize_ids([playerId for playerId in t['homePlayerIds'] if playerId in goalies]),
        'homeNumPlayers': t['homeNumPlayers']
    })

# %%
df = pd.DataFrame(serialized_shifts)
df.head()
# Out:
#        gameId  time  awayNumPlayers               awayFwdIds       awayDefIds  \
# 0  2021030143     0               6  8475184_8476459_8478366  8476885_8480817
# 1  2021030143     1               6  8475184_8476459_8478366  8476885_8480817
# 2  2021030143     2               6  8475184_8476459_8478366  8476885_8480817
# 3  2021030143     3               6  8475184_8476459_8478366  8476885_8480817
# 4  2021030143     4               6  8475184_8476459_8478366  8476885_8480817
#
#   awayGoalieIds               homeFwdIds       homeDefIds homeGoalieIds  \
# 0       8478048  8471675_8475810_8477404  8471724_8476875       8475839
# 1       8478048  8471675_8475810_8477404  8471724_8476875       8475839
# 2       8478048  8471675_8475810_8477404  8471724_8476875       8475839
# 3       8478048  8471675_8475810_8477404  8471724_8476875       8475839
# 4       8478048  8471675_8475810_8477404  8471724_8476875       8475839
#
#    homeNumPlayers
# 0               6
# 1               6
# 2               6
# 3               6
# 4               6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3600 entries, 0 to 3599
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gameId          3600 non-null   int64
#  1   time            3600 non-null   int64
#  2   awayNumPlayers  3600 non-null   int64
#  3   awayFwdIds      3600 non-null   object
#  4   awayDefIds      3600 non-null   object
#  5   awayGoalieIds   3600 non-null   object
#  6   homeFwdIds      3600 non-null   object
#  7   homeDefIds      3600 non-null   object
#  8   homeGoalieIds   3600 non-null   object
#  9   homeNumPlayers  3600 non-null   int64
# dtypes: int64(4), object(6)
# memory usage: 281.4+ KB

# %% [markdown]
# ### Create minutes df

# %%
# compute scenario of each timeframe
numHome = df['homeNumPlayers']
numAway = df['awayNumPlayers']
df['scenario'] = np.where((numHome==6) & (numAway==6), '5on5',
                         np.where((numHome==6) & (numAway==5), '5on4',
                                 np.where((numHome==5) & (numAway==6), '5on4',
                                         np.where((numHome==5) & (numAway==5), '4on4',
                                                 np.where((numHome==5) & (numAway==4), '4on3',
                                                         np.where((numHome==4) & (numAway==5), '4on3', '3on3')
                                                         )
                                                 )
                                         )
                                 )
                         )
df['scenario'] = np.where((df['awayGoalieIds'].str.len()<7) | (df['homeGoalieIds'].str.len()<7), 
                          'emptyNet', 
                          df['scenario'])
df
# Out:
#           gameId  time  awayNumPlayers               awayFwdIds  \
# 0     2021030143     0               6  8475184_8476459_8478366
# 1     2021030143     1               6  8475184_8476459_8478366
# 2     2021030143     2               6  8475184_8476459_8478366
# 3     2021030143     3               6  8475184_8476459_8478366
# 4     2021030143     4               6  8475184_8476459_8478366
# ...          ...   ...             ...                      ...
# 3595  2021030143  3595               6  8478211_8478366_8479291
# 3596  2021030143  3596               6  8478211_8478366_8479291
# 3597  2021030143  3597               6  8478211_8478366_8479291
# 3598  2021030143  3598               6  8478211_8478366_8479291
# 3599  2021030143  3599               6  8478211_8478366_8479291
#
#            awayDefIds awayGoalieIds               homeFwdIds       homeDefIds  \
# 0     8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# 1     8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# 2     8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# 3     8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# 4     8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# ...               ...           ...                      ...              ...
# 3595  8475747_8482073       8480382  8477953_8478046_8478542  8477244_8478017
# 3596  8475747_8482073       8480382  8477953_8478046_8478542  8477244_8478017
# 3597  8475747_8482073       8480382  8477953_8478046_8478542  8477244_8478017
# 3598  8475747_8482073       8480382  8477953_8478046_8478542  8477244_8478017
# 3599  8475747_8482073       8480382  8477953_8478046_8478542  8477244_8478017
#
#      homeGoalieIds  homeNumPlayers scenario
# 0          8475839               6     5on5
# 1          8475839               6     5on5
# 2          8475839               6     5on5
# 3          8475839               6     5on5
# 4          8475839               6     5on5
# ...            ...             ...      ...
# 3595       8475839               6     5on5
# 3596       8475839               6     5on5
# 3597       8475839               6     5on5
# 3598       8475839               6     5on5
# 3599       8475839               6     5on5
#
# [3600 rows x 11 columns]

# %%
df[df['scenario']=='emptyNet']
# Out:
#           gameId  time  awayNumPlayers                       awayFwdIds  \
# 2103  2021030143  2103               6          8476458_8477429_8478550
# 2104  2021030143  2104               6          8476459_8477429_8478550
# 2105  2021030143  2105               6          8476459_8477429_8478550
# 2106  2021030143  2106               6          8476459_8477429_8478550
# 2107  2021030143  2107               6          8476459_8477429_8478550
# ...          ...   ...             ...                              ...
# 3528  2021030143  3528               6  8478550_8480078_8481554_8482109
# 3529  2021030143  3529               6  8478550_8480078_8481554_8482109
# 3530  2021030143  3530               6  8478550_8480078_8481554_8482109
# 3531  2021030143  3531               6  8478550_8480078_8481554_8482109
# 3532  2021030143  3532               6  8478550_8480078_8481554_8482109
#
#            awayDefIds awayGoalieIds                       homeFwdIds  \
# 2103  8479323_8482073       8480382          8470619_8476927_8478542
# 2104  8479323_8482073       8480382  8470619_8471675_8476927_8478542
# 2105  8479323_8482073       8480382  8471215_8471675_8477404_8478542
# 2106  8479323_8482073       8480382  8471215_8471675_8477404_8478542
# 2107  8479323_8482073       8480382  8471215_8471675_8477404_8478542
# ...               ...           ...                              ...
# 3528  8474027_8479323                        8470604_8471675_8476934
# 3529  8474027_8479323                        8470604_8471675_8476934
# 3530  8474027_8479323                        8470604_8471675_8476934
# 3531  8474027_8479323                        8470604_8471675_8476934
# 3532  8474027_8479323                        8470604_8471675_8476934
#
#                    homeDefIds homeGoalieIds  homeNumPlayers  scenario
# 2103  8471724_8476875_8477969                             6  emptyNet
# 2104          8471724_8476875                             6  emptyNet
# 2105          8471724_8476875                             6  emptyNet
# 2106          8471724_8476875                             6  emptyNet
# 2107          8471724_8476875                             6  emptyNet
# ...                       ...           ...             ...       ...
# 3528          8471724_8476875       8475839               6  emptyNet
# 3529          8471724_8478507       8475839               6  emptyNet
# 3530          8471724_8478507       8475839               6  emptyNet
# 3531          8471724_8478507       8475839               6  emptyNet
# 3532          8471724_8478507       8475839               6  emptyNet
#
# [74 rows x 11 columns]

# %%
df[['time', 'awayFwdIds', 'scenario']]
# Out:
#       time               awayFwdIds scenario
# 0        0  8475184_8476459_8478366     5on5
# 1        1  8475184_8476459_8478366     5on5
# 2        2  8475184_8476459_8478366     5on5
# 3        3  8475184_8476459_8478366     5on5
# 4        4  8475184_8476459_8478366     5on5
# ...    ...                      ...      ...
# 3595  3595  8478211_8478366_8479291     5on5
# 3596  3596  8478211_8478366_8479291     5on5
# 3597  3597  8478211_8478366_8479291     5on5
# 3598  3598  8478211_8478366_8479291     5on5
# 3599  3599  8478211_8478366_8479291     5on5
#
# [3600 rows x 3 columns]

# %%
timeframes = df.to_dict(orient='records')
timeframes[0]
# Out:
# {'gameId': 2021030143,
#  'time': 0,
#  'awayNumPlayers': 6,
#  'awayFwdIds': '8475184_8476459_8478366',
#  'awayDefIds': '8476885_8480817',
#  'awayGoalieIds': '8478048',
#  'homeFwdIds': '8471675_8475810_8477404',
#  'homeDefIds': '8471724_8476875',
#  'homeGoalieIds': '8475839',
#  'homeNumPlayers': 6,
#  'scenario': '5on5'}

# %%
shifts = []
homeTeamId = 5
awayTeamId = 3
cats = ['awayFwdIds', 'awayDefIds', 'awayGoalieIds',
       'homeFwdIds', 'homeDefIds', 'homeGoalieIds']

for cat in cats:
    teamId = homeTeamId
    if 'away' in cat:
        teamId = awayTeamId
    lineType = 'fwd'
    if 'Def' in cat:
        lineType = 'def'
    elif 'Goalie' in cat:
        lineType = 'goalie'
        
    start = 0
    cur_line = timeframes[0][cat]
    cur_scenario = timeframes[0]['scenario']

    for i in range(1,len(timeframes)):
        if timeframes[i][cat] != cur_line or timeframes[i]['scenario'] != cur_scenario:
            if cur_line != '':
                shifts.append({
                    'start': start,
                    'end': i,
                    'duration': i-start,
                    'gameId': gameId,
                    'teamId': teamId,
                    'lineId': cur_line,
                    'lineType': lineType,
                    'scenario': cur_scenario
                })

            start = i
            cur_line = timeframes[i][cat]
            cur_scenario = timeframes[i]['scenario']
    shifts.append({
        'start': start,
        'end': i,
        'duration': i-start,
        'gameId': gameId,
        'teamId': teamId,
        'lineId': cur_line,
        'lineType': lineType,
        'scenario': cur_scenario
    })

# %%
df_shifts = pd.DataFrame(shifts)

# %%
df_shifts.sort_values(['end', 'start'], ascending=False)
# Out:
#      start   end  duration      gameId  teamId                   lineId  \
# 502   3568  3599        31  2021030143       5  8477953_8478046_8478542
# 158   3533  3599        66  2021030143       3  8478211_8478366_8479291
# 291   3533  3599        66  2021030143       3          8475747_8482073
# 308   3533  3599        66  2021030143       3                  8480382
# 640   3533  3599        66  2021030143       5          8477244_8478017
# ..     ...   ...       ...         ...     ...                      ...
# 310     35    42         7  2021030143       5  8471675_8475810_8478046
# 0        0    41        41  2021030143       3  8475184_8476459_8478366
# 160     34    35         1  2021030143       3          8479323_8480817
# 309      0    35        35  2021030143       5  8471675_8475810_8477404
# 159      0    34        34  2021030143       3          8476885_8480817
#
#     lineType scenario
# 502      fwd     5on5
# 158      fwd     5on5
# 291      def     5on5
# 308   goalie     5on5
# 640      def     5on5
# ..       ...      ...
# 310      fwd     5on5
# 0        fwd     5on5
# 160      def     5on5
# 309      fwd     5on5
# 159      def     5on5
#
# [658 rows x 8 columns]

# %%
df_shifts[(df_shifts['teamId']==3) & (df_shifts['lineType']=='fwd')]
# Out:
#      start   end  duration  teamId                                   lineId  \
# 0        0    41        41       3                  8475184_8476459_8478366
# 1       41    42         1       3                  8475184_8478366_8478550
# 2       42    43         1       3                  8475184_8476458_8478550
# 3       43    80        37       3                  8476458_8477429_8478550
# 4       80   117        37       3                  8480078_8481554_8482109
# ..     ...   ...       ...     ...                                      ...
# 154   3439  3456        17       3                  8475184_8476459_8478366
# 155   3456  3466        10       3  8475184_8476458_8476459_8477429_8478550
# 156   3466  3480        14       3                  8480078_8481554_8482109
# 157   3480  3533        53       3          8478550_8480078_8481554_8482109
# 158   3533  3599        66       3                  8478211_8478366_8479291
#
#     lineType  scenario
# 0        fwd      5on5
# 1        fwd      5on5
# 2        fwd      5on5
# 3        fwd      5on5
# 4        fwd      5on5
# ..       ...       ...
# 154      fwd      5on5
# 155      fwd  emptyNet
# 156      fwd      5on5
# 157      fwd  emptyNet
# 158      fwd      5on5
#
# [159 rows x 7 columns]

# %%
df_shifts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   start     658 non-null    int64
#  1   end       658 non-null    int64
#  2   duration  658 non-null    int64
#  3   teamId    658 non-null    int64
#  4   lineId    658 non-null    object
#  5   lineType  658 non-null    object
#  6   scenario  658 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 36.1+ KB

# %% [markdown]
# ### Merge shot and timeframe df

# %%
df_shot_players = df_shots.merge(df, on='time')
df_shot_players
# Out:
#      shooterId  goalieId  blockerId  teamId     x     y  time          type  \
# 0      8475810   8478048          0       5 -52.0  21.0    27          SHOT
# 1      8476458   8475839          0       3  79.0  15.0    79          SHOT
# 2      8481554   8475839          0       3  74.0  30.0    85          SHOT
# 3      8482109         0          0       3  83.0  -7.0    87   MISSED_SHOT
# 4      8476934   8478048          0       5 -89.0   8.0   117          GOAL
# ..         ...       ...        ...     ...   ...   ...   ...           ...
# 125    8478550         0    8471724       5  72.0  -8.0  3462  BLOCKED_SHOT
# 126    8477404         0          0       5  31.0 -38.0  3466          GOAL
# 127    8478550   8475839          0       3  53.0  35.0  3519          SHOT
# 128    8476934         0          0       5 -38.0 -23.0  3532   MISSED_SHOT
# 129    8470604         0          0       5 -64.0  -2.0  3533          GOAL
#
#          gameId  awayNumPlayers                               awayFwdIds  \
# 0    2021030143               6                  8475184_8476459_8478366
# 1    2021030143               6                  8476458_8477429_8478550
# 2    2021030143               6                  8480078_8481554_8482109
# 3    2021030143               6                  8480078_8481554_8482109
# 4    2021030143               6                  8471817_8478211_8479291
# ..          ...             ...                                      ...
# 125  2021030143               6  8475184_8476458_8476459_8477429_8478550
# 126  2021030143               6                  8480078_8481554_8482109
# 127  2021030143               6          8478550_8480078_8481554_8482109
# 128  2021030143               6          8478550_8480078_8481554_8482109
# 129  2021030143               6                  8478211_8478366_8479291
#
#           awayDefIds awayGoalieIds               homeFwdIds       homeDefIds  \
# 0    8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# 1    8475747_8482073       8478048  8471215_8477953_8478046  8477969_8478507
# 2    8475747_8482073       8478048  8470604_8475722_8476934  8477244_8478017
# 3    8475747_8482073       8478048  8470604_8475722_8476934  8477244_8478017
# 4    8476885_8480817       8478048  8470619_8476927_8478542  8471724_8476875
# ..               ...           ...                      ...              ...
# 125          8479323                8471675_8475810_8477404  8471724_8476875
# 126  8474027_8479323       8480382  8470604_8476927_8476934  8471724_8476875
# 127  8474027_8479323                8470604_8471675_8476934  8471724_8476875
# 128  8474027_8479323                8470604_8471675_8476934  8471724_8478507
# 129  8475747_8482073       8480382  8470619_8475722_8476927  8477244_8478017
#
#     homeGoalieIds  homeNumPlayers  scenario
# 0         8475839               6      5on5
# 1         8475839               6      5on5
# 2         8475839               6      5on5
# 3         8475839               6      5on5
# 4         8475839               6      5on5
# ..            ...             ...       ...
# 125       8475839               6  emptyNet
# 126       8475839               6      5on5
# 127       8475839               6  emptyNet
# 128       8475839               6  emptyNet
# 129       8475839               6      5on5
#
# [130 rows x 18 columns]

# %% [markdown]
# ## Example of getting Data from datasets

# %%
line_str = '8477969_8478507'
mp = df_shifts[df_shifts['lineId']==line_str]['duration'].sum() / 60

# %%
tid = 5
# cf = len(df_shot_players[(df_shot_players['awayFwdIds']==line_str) & (df_shot_players['teamId']==tid)])
# ca = len(df_shot_players[(df_shot_players['awayFwdIds']==line_str) & (df_shot_players['teamId']!=tid)])

cf = len(df_shot_players[(df_shot_players['homeDefIds']==line_str) & (df_shot_players['teamId']==tid)])
ca = len(df_shot_players[(df_shot_players['homeDefIds']==line_str) & (df_shot_players['teamId']!=tid)])
cr = cf - ca

# %%
df_shot_players[(df_shot_players['homeDefIds']==line_str)]
# Out:
#      shooterId  goalieId  blockerId  teamId     x     y  time          type  \
# 1      8476458   8475839          0       3  79.0  15.0    79          SHOT
# 19     8470604   8478048          0       5 -82.0   1.0   498          GOAL
# 20     8475722   8478048          0       5 -80.0  -9.0   534          SHOT
# 23     8478542   8478048          0       5 -77.0  -0.0   631          GOAL
# 24     8477969         0    8479291       3 -54.0 -15.0   662  BLOCKED_SHOT
# 30     8478542   8478048          0       5 -60.0  -3.0   915          GOAL
# 35     8477969         0    8478366       3 -49.0 -23.0  1049  BLOCKED_SHOT
# 36     8478366         0          0       3  55.0  13.0  1059   MISSED_SHOT
# 38     8475722   8478048          0       5 -37.0 -17.0  1156          SHOT
# 42     8477953         0          0       5 -55.0 -14.0  1194   MISSED_SHOT
# 43     8477953         0          0       5 -60.0 -23.0  1194   MISSED_SHOT
# 46     8478507         0          0       5 -38.0  28.0  1260   MISSED_SHOT
# 47     8474027         0          0       3  40.0  16.0  1304   MISSED_SHOT
# 48     8480078   8475839          0       3  67.0  -7.0  1307          SHOT
# 56     8478211         0    8477969       5  58.0 -20.0  1558  BLOCKED_SHOT
# 57     8478366   8475839          0       3  69.0 -10.0  1611          GOAL
# 58     8478550         0    8478507       5  63.0  -4.0  1634  BLOCKED_SHOT
# 59     8476458   8475839          0       3  72.0 -11.0  1639          SHOT
# 62     8478550   8475839          0       3  70.0  23.0  1678          GOAL
# 63     8474027         0          0       3  34.0  -3.0  1714   MISSED_SHOT
# 64     8478366         0    8478507       5  80.0  -1.0  1735  BLOCKED_SHOT
# 72     8478366   8475839          0       3  41.0  -8.0  1955          SHOT
# 73     8477953         0          0       5 -56.0 -14.0  1968   MISSED_SHOT
# 74     8482073         0          0       3  52.0  -2.0  1991   MISSED_SHOT
# 76     8479323   8475839          0       3  36.0 -19.0  2087          SHOT
# 112    8478046   8480382          0       5 -75.0  10.0  3062          GOAL
# 113    8477969         0          0       5 -37.0 -16.0  3089   MISSED_SHOT
# 117    8470604   8480382          0       5 -43.0  -8.0  3186          SHOT
# 120    8477953         0          0       5 -67.0  16.0  3289   MISSED_SHOT
# 122    8477969         0    8477429       3 -48.0 -22.0  3405  BLOCKED_SHOT
# 123    8478507         0    8476458       3 -62.0   7.0  3426  BLOCKED_SHOT
#
#          gameId  awayNumPlayers               awayFwdIds       awayDefIds  \
# 1    2021030143               6  8476458_8477429_8478550  8475747_8482073
# 19   2021030143               6  8476458_8477429_8478550  8475747_8482073
# 20   2021030143               6  8476458_8477429_8478550  8474027_8479323
# 23   2021030143               6  8471817_8478211_8479291  8475747_8482073
# 24   2021030143               6  8471817_8478211_8479291  8475747_8482073
# 30   2021030143               6  8471817_8478211_8479291  8474027_8479323
# 35   2021030143               6  8475184_8476459_8478366  8475747_8476885
# 36   2021030143               6  8475184_8478366_8480078  8475747_8482073
# 38   2021030143               6  8476458_8477429_8478550  8476885_8480817
# 42   2021030143               6  8475184_8476459_8478366  8475747_8482073
# 43   2021030143               6  8475184_8476459_8478366  8475747_8482073
# 46   2021030143               6  8476458_8477429_8478550  8474027_8479323
# 47   2021030143               6  8480078_8481554_8482109  8474027_8479323
# 48   2021030143               6  8480078_8481554_8482109  8479323_8482073
# 56   2021030143               6  8471817_8478211_8479291  8474027_8479323
# 57   2021030143               6  8476458_8477429_8478550  8475747_8482073
# 58   2021030143               6  8476458_8477429_8478550  8475747_8482073
# 59   2021030143               6  8476458_8477429_8478550  8475747_8482073
# 62   2021030143               6  8475184_8476459_8478366  8476885_8480817
# 63   2021030143               6  8475184_8476459_8478366  8474027_8479323
# 64   2021030143               6  8475184_8476459_8478366  8474027_8479323
# 72   2021030143               6  8475184_8480078_8482109  8479323_8482073
# 73   2021030143               6  8480078_8481554_8482109  8475747_8482073
# 74   2021030143               6  8480078_8481554_8482109  8475747_8482073
# 76   2021030143               6  8476458_8477429_8478550  8479323_8482073
# 112  2021030143               6  8480078_8481554_8482109  8476885_8480817
# 113  2021030143               6  8480078_8481554_8482109  8476885_8480817
# 117  2021030143               6  8475184_8476459_8478366  8474027_8479323
# 120  2021030143               6  8475184_8476459_8478366  8476885_8480817
# 122  2021030143               6  8476458_8477429_8478550  8475747_8482073
# 123  2021030143               6  8476458_8477429_8478550  8475747_8482073
#
#     awayGoalieIds               homeFwdIds       homeDefIds homeGoalieIds  \
# 1         8478048  8471215_8477953_8478046  8477969_8478507       8475839
# 19        8478048  8475722_8476927_8476934  8477969_8478507       8475839
# 20        8478048  8475722_8476927_8476934  8477969_8478507       8475839
# 23        8478048  8475722_8476927_8476934  8477969_8478507       8475839
# 24        8478048  8475722_8476927_8476934  8477969_8478507       8475839
# 30        8478048  8470619_8476927_8478542  8477969_8478507       8475839
# 35        8478048  8471675_8475810_8477404  8477969_8478507       8475839
# 36        8478048  8471675_8477404_8477953  8477969_8478507       8475839
# 38        8478048  8470604_8475722_8476934  8477969_8478507       8475839
# 42        8478048  8470604_8471215_8477953  8477969_8478507       8475839
# 43        8478048  8470604_8471215_8477953  8477969_8478507       8475839
# 46        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 47        8480382  8470604_8475722_8476934  8477969_8478507       8475839
# 48        8480382  8470604_8475722_8476934  8477969_8478507       8475839
# 56        8480382  8471675_8475810_8477404  8477969_8478507       8475839
# 57        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 58        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 59        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 62        8480382  8471675_8475810_8477404  8477969_8478507       8475839
# 63        8480382  8471675_8475810_8477404  8477969_8478507       8475839
# 64        8480382  8471215_8475810_8477404  8477969_8478507       8475839
# 72        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 73        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 74        8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 76        8480382  8470619_8476927_8478542  8477969_8478507       8475839
# 112       8480382  8471675_8475810_8477404  8477969_8478507       8475839
# 113       8480382  8471675_8475810_8477404  8477969_8478507       8475839
# 117       8480382  8470604_8475722_8476934  8477969_8478507       8475839
# 120       8480382  8471215_8477953_8478046  8477969_8478507       8475839
# 122       8480382  8471675_8475810_8477404  8477969_8478507       8475839
# 123       8480382  8471215_8475810_8478046  8477969_8478507       8475839
#
#      homeNumPlayers scenario
# 1                 6     5on5
# 19                6     5on5
# 20                6     5on5
# 23                6     5on5
# 24                6     5on5
# 30                6     5on5
# 35                6     5on5
# 36                6     5on5
# 38                6     5on5
# 42                6     5on5
# 43                6     5on5
# 46                6     5on5
# 47                6     5on5
# 48                6     5on5
# 56                6     5on5
# 57                6     5on5
# 58                6     5on5
# 59                6     5on5
# 62                6     5on5
# 63                6     5on5
# 64                6     5on5
# 72                6     5on5
# 73                6     5on5
# 74                6     5on5
# 76                6     5on5
# 112               6     5on5
# 113               6     5on5
# 117               6     5on5
# 120               6     5on5
# 122               6     5on5
# 123               6     5on5

# %%
print('minutes played: ' + str(mp))
print('corsi for: ' + str(cf))
print('corsi against: ' + str(ca))
print('corsi relative: ' + str(cr))
# Out:
# minutes played: 13.416666666666666
# corsi for: 16
# corsi against: 15
# corsi relative: 1

# %%
df_shot_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 0 to 129
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   shooterId       130 non-null    int64
#  1   goalieId        130 non-null    int64
#  2   blockerId       130 non-null    int64
#  3   teamId          130 non-null    int64
#  4   x               130 non-null    float64
#  5   y               130 non-null    float64
#  6   time            130 non-null    int64
#  7   type            130 non-null    object
#  8   gameId          130 non-null    int64
#  9   awayNumPlayers  130 non-null    int64
#  10  awayFwdIds      130 non-null    object
#  11  awayDefIds      130 non-null    object
#  12  awayGoalieIds   130 non-null    object
#  13  homeFwdIds      130 non-null    object
#  14  homeDefIds      130 non-null    object
#  15  homeGoalieIds   130 non-null    object
#  16  homeNumPlayers  130 non-null    int64
#  17  scenario        130 non-null    object
# dtypes: float64(2), int64(8), object(8)
# memory usage: 23.4+ KB

# %%
# df_tmp = df_shot_players[['shooterId', 'gameId']].copy()
# df_tmp['shotId'] = [i for i in range(0, len(df_tmp))]
# df_tmp

# %%
# df_shot_players.to_dict(orient='records')
df_shot_players.to_csv('data/shotSample.csv', index=False)

# %%
# with open('data/shotSample.json') as f:
#     shot_data =

# %%
# df_t = pd.read_json('data/shotSample.json')
df_t = pd.read_json('data/shotSample.json', dtype={
    'awayFwdIds': 'str',
    'awayDefIds': 'str',
    'awayGoalieIds': 'str',
    'homeFwdIds': 'str',
    'homeDefIds': 'str',
    'homeGoalieIds': 'str',
})#.fillna('')
# df_t.fillna('')
# df_t['awayGoalieIds'] = df_t['awayGoalieIds'].astype(str)
df_t
# Out:
#      shooterId  goalieId  blockerId  teamId   x   y  time          type  \
# 0      8475810   8478048          0       5 -52  21    27          SHOT
# 1      8476458   8475839          0       3  79  15    79          SHOT
# 2      8481554   8475839          0       3  74  30    85          SHOT
# 3      8482109         0          0       3  83  -7    87   MISSED_SHOT
# 4      8476934   8478048          0       5 -89   8   117          GOAL
# ..         ...       ...        ...     ...  ..  ..   ...           ...
# 125    8478550         0    8471724       5  72  -8  3462  BLOCKED_SHOT
# 126    8477404         0          0       5  31 -38  3466          GOAL
# 127    8478550   8475839          0       3  53  35  3519          SHOT
# 128    8476934         0          0       5 -38 -23  3532   MISSED_SHOT
# 129    8470604         0          0       5 -64  -2  3533          GOAL
#
#          gameId  awayNumPlayers                               awayFwdIds  \
# 0    2021030143               6                  8475184_8476459_8478366
# 1    2021030143               6                  8476458_8477429_8478550
# 2    2021030143               6                  8480078_8481554_8482109
# 3    2021030143               6                  8480078_8481554_8482109
# 4    2021030143               6                  8471817_8478211_8479291
# ..          ...             ...                                      ...
# 125  2021030143               6  8475184_8476458_8476459_8477429_8478550
# 126  2021030143               6                  8480078_8481554_8482109
# 127  2021030143               6          8478550_8480078_8481554_8482109
# 128  2021030143               6          8478550_8480078_8481554_8482109
# 129  2021030143               6                  8478211_8478366_8479291
#
#           awayDefIds awayGoalieIds               homeFwdIds       homeDefIds  \
# 0    8476885_8480817       8478048  8471675_8475810_8477404  8471724_8476875
# 1    8475747_8482073       8478048  8471215_8477953_8478046  8477969_8478507
# 2    8475747_8482073       8478048  8470604_8475722_8476934  8477244_8478017
# 3    8475747_8482073       8478048  8470604_8475722_8476934  8477244_8478017
# 4    8476885_8480817       8478048  8470619_8476927_8478542  8471724_8476875
# ..               ...           ...                      ...              ...
# 125          8479323                8471675_8475810_8477404  8471724_8476875
# 126  8474027_8479323       8480382  8470604_8476927_8476934  8471724_8476875
# 127  8474027_8479323                8470604_8471675_8476934  8471724_8476875
# 128  8474027_8479323                8470604_8471675_8476934  8471724_8478507
# 129  8475747_8482073       8480382  8470619_8475722_8476927  8477244_8478017
#
#     homeGoalieIds  homeNumPlayers  scenario
# 0         8475839               6      5on5
# 1         8475839               6      5on5
# 2         8475839               6      5on5
# 3         8475839               6      5on5
# 4         8475839               6      5on5
# ..            ...             ...       ...
# 125       8475839               6  emptyNet
# 126       8475839               6      5on5
# 127       8475839               6  emptyNet
# 128       8475839               6  emptyNet
# 129       8475839               6      5on5
#
# [130 rows x 18 columns]

# %%
df_t['awayGoalieIds'].fillna('').astype(str)
# Out:
# 0      8478048.0
# 1      8478048.0
# 2      8478048.0
# 3      8478048.0
# 4      8478048.0
#          ...
# 125
# 126    8480382.0
# 127
# 128
# 129    8480382.0
# Name: awayGoalieIds, Length: 130, dtype: object

# %%
df_t['awayDefIds']
# Out:
# 0      84768858480817
# 1      84757478482073
# 2      84757478482073
# 3      84757478482073
# 4      84768858480817
#             ...
# 125           8479323
# 126    84740278479323
# 127    84740278479323
# 128    84740278479323
# 129    84757478482073
# Name: awayDefIds, Length: 130, dtype: int64

# %% [markdown]
# ##### Save shift data to file

# %%
df_shifts
# Out:
#      start   end  duration      gameId  teamId                   lineId  \
# 0        0    41        41  2021030143       3  8475184_8476459_8478366
# 1       41    42         1  2021030143       3  8475184_8478366_8478550
# 2       42    43         1  2021030143       3  8475184_8476458_8478550
# 3       43    80        37  2021030143       3  8476458_8477429_8478550
# 4       80   117        37  2021030143       3  8480078_8481554_8482109
# ..     ...   ...       ...         ...     ...                      ...
# 653   2909  3456       547  2021030143       5                  8475839
# 654   3456  3466        10  2021030143       5                  8475839
# 655   3466  3480        14  2021030143       5                  8475839
# 656   3480  3533        53  2021030143       5                  8475839
# 657   3533  3599        66  2021030143       5                  8475839
#
#     lineType  scenario
# 0        fwd      5on5
# 1        fwd      5on5
# 2        fwd      5on5
# 3        fwd      5on5
# 4        fwd      5on5
# ..       ...       ...
# 653   goalie      5on5
# 654   goalie  emptyNet
# 655   goalie      5on5
# 656   goalie  emptyNet
# 657   goalie      5on5
#
# [658 rows x 8 columns]

# %%
df_shifts.to_json('data/shiftSample.json', orient='records')

# %%
df_t = pd.read_json('data/shiftSample.json', dtype={
    'lineId': 'str'
})
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   start     658 non-null    int64
#  1   end       658 non-null    int64
#  2   duration  658 non-null    int64
#  3   gameId    658 non-null    int64
#  4   teamId    658 non-null    int64
#  5   lineId    658 non-null    object
#  6   lineType  658 non-null    object
#  7   scenario  658 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 41.2+ KB

# %% [markdown]
# ##### Save roster data

# %%
df_roster = pd.DataFrame(roster)
df_roster['height'] = df_roster['height'].str[:1].astype(int)*12 + df_roster['height'].str[3:-1].astype(int)
df_roster.to_json('data/rosterSample.json', orient='records')

# %%
df_t = pd.read_json('data/rosterSample.json')
# df_t

# %% [markdown]
# ##### Save schedule data

# %%
gameInfo
gameInfo2 = [
    {'gameId': 2021030143,
     'dateTime': '2022-05-07T23:00:00Z',
     'awayTeamId': 3,
     'homeTeamId': 5},
    {'gameId': 2021030147,
    'dateTime': '2022-05-09T23:00:00Z',
    'awayTeamId': 5,
    'homeTeamId': 3}
]
gameInfo2
# Out:
# [{'gameId': 2021030143,
#   'dateTime': '2022-05-07T23:00:00Z',
#   'awayTeamId': 3,
#   'homeTeamId': 5},
#  {'gameId': 2021030147,
#   'dateTime': '2022-05-09T23:00:00Z',
#   'awayTeamId': 5,
#   'homeTeamId': 3}]

# %%
df_schedule = pd.DataFrame(gameInfo2)
df_schedule.to_json('data/scheduleSample.json', orient='records')

# %%
df_t = pd.read_json('data/scheduleSample.json')
df_t
# Out:
#        gameId                  dateTime  awayTeamId  homeTeamId
# 0  2021030143 2022-05-07 23:00:00+00:00           3           5
# 1  2021030147 2022-05-09 23:00:00+00:00           5           3

# %% [markdown]
# ##### Save teams data

# %%
df_teams = pd.DataFrame(teams)
df_teams.to_json('data/teamsSample.json', orient='records')

# %%
df_t = pd.read_json('data/teamsSample.json')
df_t.columns
# Out:
# Index(['teamId', 'name', 'locationName', 'teamName', 'abbreviation',
#        'division', 'conference', 'firstYearOfPlay', 'venue', 'timezone'],
#       dtype='object')
